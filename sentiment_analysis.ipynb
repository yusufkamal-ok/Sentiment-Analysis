# %%
#library & package. 
import pandas as pd, numpy as np, matplotlib.pyplot as plt
import json, tweepy, requests, re, string
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup as bs

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import TextVectorization
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %% [markdown]
# Business Understanding

# %% [markdown]
# Topik yang dipilih adalah fresh graduate.Topik tersebut dipilih karena sekarang sedang banyak mahasiswa yang baru lulus/wisuda pada bulan-bulan ini.Karena hal tersebut masyrakat akan banyak update pada sosial media salah satunya twiter terkait fresh graduate,mulai dari ngetwet pengalaman kuliah,sampai dengan info lowongan.Dari topik tersebut dapat dibuat klasifikasi  terkait artikel/tweet tentang fresh graduate, untuk mengetahui ada berapa banyak kategori yang bisa dibuat dan detail terkait kategori tersebut.

# %% [markdown]
# Data Collection

# %%
with open("token.json")as f:
  tokens = json.load(f)

bearer_token = tokens['bearer_token']
api_key = tokens['api_key']
api_key_secret = tokens['api_key_secret']
access_token = tokens['access_token']
access_token_secret = tokens['access_token_secret']

# %%
api = tweepy.Client(bearer_token=bearer_token, wait_on_rate_limit=True)

# %%
query = "fresh graduate -is:retweet lang:id"

response = tweepy.Paginator(api.search_recent_tweets,
                          query = query,
                          start_time = "2022-09-01T00:00:00Z",
                          end_time = "2022-09-03T00:00:00Z",
                          max_results=100
                          ).flatten(limit=2000)
tweets = [tweet.text.strip() for tweet in response]

# %%
df_tweets = pd.DataFrame(tweets, columns=["artikel"])
df_tweets
# Out:
#                                                artikel
# 0    Lowongan Kerja Fresh Graduate Program Samosir ...
# 1    Lowongan Kerja Indonesia Lulusan D3 September ...
# 2    Lowongan Kerja Fresh Graduate Program Belitung...
# 3    oh begini nasibnya fresh graduate yang pengang...
# 4    Lowongan Kerja Fresh Graduate Program Bangka –...
# ..                                                 ...
# 203  Info loker dom bogor dong buat SMK fresh gradu...
# 204  @collegemenfess sama aja nder, tapi kalo kerja...
# 205  Fresh Graduate Wajib Tahu, Ini Hal yang Mesti ...
# 206  [cm] di LinkedIn ada ga yang buka lowongan bua...
# 207   @hrdbacot fresh graduate boleh lamar ga kak? 🙏🙏🙏
#
# [208 rows x 1 columns]

# %%
# data tambahan dari website
user_agent='Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/602.2.14 (KHTML, like Gecko) Version/10.0.1 Safari/602.2.14'
headers = {'User-Agent': user_agent,'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8'}

alamat = "https://www.kompas.com/edu/read/2022/09/04/132700571/tips-melamar-kerja-bagi-fresh-graduate-bukan-dari-universitas-ternama"
req = Request(alamat, headers=headers)
html = urlopen(req)

# %%
data = bs(html, 'html.parser')
box = data.find("div",{"class":"read__content"})

hidelabel = box.findAll('strong')
for delete in hidelabel:
    delete.decompose()
items = box.findAll("p")
hasil = [item.get_text() for item in items]

# %%
print(hasil)
# Out:
# ['', ' - Saat ini perusahaan sangat spesifik dalam memberikan persyaratan dalam proses rekrutmen karyawan. Hal ini tentu menjadi tantangan tersendiri bagi para fresh graduate.', 'Bahkan di beberapa persyaratan lowongan kerja, tertera syarat kandidat harus berasal dari universitas ternama dengan peringkat terbaik.', 'Lantas bagaimana fresh graduate dari universitas yang kurang terkenal? Syarat tersebut tentu menjadi beban tersendiri karena kinerja seseorang tidak hanya ditentukan berdasarkan almamater semata.', 'Menyikapi kondisi ini, ada beberapa tips yang bisa dilakukan para fresh graduate. Melansir dari laman website penyedia lowongan kerja JobStreet, membagikan tips melamar pekerjaan bagi fresh graduate dari universitas yang kurang ternama. Apa saja tipsnya? Yuk simak informasi berikut ini:', '', '', 'Meski kamu bukan lulusan dari kampus ternama, kualitas dirimu bisa diperlihatkan dari pengalaman berorganisasi selama menjadi mahasiswa.', 'Dengan aktif berorganisasi, kamu bisa memiliki berbagai pengalaman baru yang bisa dicantumkan dalam CV. Bagian HR bisa menilai kamu lebih tinggi karena setidaknya kamu sudah familiar dengan lingkungan yang mengandalkan kerja sama dan menuntut profesionalisme.', 'Mengikuti organisasi juga bisa menjadi bukti untuk beberapa soft skill yang dicantumkan dalam CV kamu.', '', 'Selain aktif di organisasi kampus, kamu juga bisa mengikuti kegiatan volunteer. Jika sudah lulus, kamu lebih leluasa untuk mengikuti kegiatan menjadi relawan. Kamu bisa ikut volunteer yang diadakan komunitas-komunitas kecil hingga NGO yang cukup terkenal.']

# %%
df1 = pd.DataFrame(hasil)
df1.columns = ['artikel']
df1
# Out:
#                                               artikel
# 0
# 1    - Saat ini perusahaan sangat spesifik dalam m...
# 2   Bahkan di beberapa persyaratan lowongan kerja,...
# 3   Lantas bagaimana fresh graduate dari universit...
# 4   Menyikapi kondisi ini, ada beberapa tips yang ...
# 5
# 6
# 7   Meski kamu bukan lulusan dari kampus ternama, ...
# 8   Dengan aktif berorganisasi, kamu bisa memiliki...
# 9   Mengikuti organisasi juga bisa menjadi bukti u...
# 10
# 11  Selain aktif di organisasi kampus, kamu juga b...

# %%
# gabungan data tweets dan sumber tambahan
df = pd.concat([df1,df_tweets.loc[:]]).reset_index(drop=True)
df
# Out:
#                                                artikel
# 0
# 1     - Saat ini perusahaan sangat spesifik dalam m...
# 2    Bahkan di beberapa persyaratan lowongan kerja,...
# 3    Lantas bagaimana fresh graduate dari universit...
# 4    Menyikapi kondisi ini, ada beberapa tips yang ...
# ..                                                 ...
# 215  Info loker dom bogor dong buat SMK fresh gradu...
# 216  @collegemenfess sama aja nder, tapi kalo kerja...
# 217  Fresh Graduate Wajib Tahu, Ini Hal yang Mesti ...
# 218  [cm] di LinkedIn ada ga yang buka lowongan bua...
# 219   @hrdbacot fresh graduate boleh lamar ga kak? 🙏🙏🙏
#
# [220 rows x 1 columns]

# %%
# to csv
df.to_csv('fresh_graduate.csv')

# %% [markdown]
# Text Preprocessing

# %%
#case folding
def case_folding(text):
    kalimat = re.sub("(@[A-Za-z0-9]+)|([^A-Za-z \t])|(\w+:\/\/\S+)|(\d+)", " ", text.lower())
    hasil = kalimat.translate(str.maketrans("","",string.punctuation)).strip()
    return hasil

# %%
# stopword bahasa indonesai
stopword = pd.read_csv('stopwords.txt',names=['stw'],header=None)
stopwords = stopword['stw'].values.tolist()
# ditambah kata kunci yang dicari
tambah = 'fresh'
tambah1 = 'graduate'
stopwords.append(tambah)
stopwords.append(tambah1)

# %%
# stopword
def stop_words(text):
    texts = text.split()
    
    resultword = [word for word in texts if word not in stopwords]
    hasil = ' '.join(resultword)
    return hasil

# %%
#  slang word
slangWords = ['sabi','sabun','sabeb','kemek','kilab','cabs','sutup','selow',' woles','baper','php','rokum','sotoy','btw']
def slang_words(text):
    texts = text.split()
    
    resultword = [word for word in texts if word not in slangWords]
    hasil = ' '.join(resultword)
    return hasil

# %%
df['clean_artikel'] = df['artikel'].apply(case_folding)
df['clean_artikel'] = df['clean_artikel'].apply(stop_words)
df['clean_artikel'] = df['clean_artikel'].apply(slang_words)
df
# Out:
#                                                artikel  \
# 0
# 1     - Saat ini perusahaan sangat spesifik dalam m...
# 2    Bahkan di beberapa persyaratan lowongan kerja,...
# 3    Lantas bagaimana fresh graduate dari universit...
# 4    Menyikapi kondisi ini, ada beberapa tips yang ...
# ..                                                 ...
# 215  Info loker dom bogor dong buat SMK fresh gradu...
# 216  @collegemenfess sama aja nder, tapi kalo kerja...
# 217  Fresh Graduate Wajib Tahu, Ini Hal yang Mesti ...
# 218  [cm] di LinkedIn ada ga yang buka lowongan bua...
# 219   @hrdbacot fresh graduate boleh lamar ga kak? 🙏🙏🙏
#
#                                          clean_artikel
# 0
# 1    perusahaan spesifik persyaratan proses rekrutm...
# 2    persyaratan lowongan kerja tertera syarat kand...
# 3    lantas universitas terkenal syarat beban terse...
# 4    menyikapi kondisi tips melansir laman website ...
# ..                                                 ...
# 215  info loker dom bogor smk butuh kerjaan banget ...
# 216  aja nder kalo kerja praktek kayaknya undergrad...
# 217              wajib mesti diperhatikan bikin cv ats
# 218  cm linkedin ga buka lowongan magang statusnya ...
# 219                                       lamar ga kak
#
# [220 rows x 2 columns]

# %% [markdown]
# Text Data Analysis

# %%
# Distribusi Frekuensi karakter per artikel
bin_range = np.arange(0, 260, 10)
df['clean_artikel'] .str.len().hist(bins=bin_range)
plt.show()

# %%
# Distribusi panjang kata per artikel
df['clean_artikel'].str.split().apply(lambda x : [len(i) for i in x]).map(lambda x: len(x)).hist()
plt.show()

# %%
# Distribusi panjang rata-rata kata per artikel
df['clean_artikel'].str.split().apply(lambda x : [len(i) for i in x]).map(lambda x: np.mean(x)).hist()
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
df['clean_artikel_frequency']  = df['clean_artikel'] .apply(lambda x: word_tokenize(x))
cleans = [word for clean in df['clean_artikel_frequency']  for word in clean]
fqdist = FreqDist(cleans)
most_common_word = fqdist.most_common(1000)

# %%
fqdist.plot(20,cumulative=False)

plt.show()

# %%
most_common_word
# Out:
# [('kerja', 127),
#  ('lowongan', 77),
#  ('pt', 39),
#  ('smk', 37),
#  ('lulusan', 34),
#  ('ga', 33),
#  ('sma', 33),
#  ('yg', 32),
#  ('program', 28),
#  ('orang', 27),
#  ('indah', 25),
#  ('reksa', 25),
#  ('equality', 25),
#  ('jakarta', 22),
#  ('ya', 22),
#  ('loker', 21),
#  ('s', 19),
#  ('jujur', 19),
#  ('selatan', 19),
#  ('pengalaman', 18),
#  ('cabang', 18),
#  ('disiplin', 18),
#  ('hubungi', 18),
#  ('wa', 18),
#  ('kalo', 17),
#  ('aja', 17),
#  ('perusahaan', 16),
#  ('info', 13),
#  ('udah', 13),
#  ('cari', 13),
#  ('september', 12),
#  ('syarat', 11),
#  ('cv', 11),
#  ('melamar', 10),
#  ('d', 10),
#  ('kuliah', 10),
#  ('nya', 10),
#  ('dunia', 9),
#  ('amp', 9),
#  ('banget', 9),
#  ('pekerjaan', 8),
#  ('indonesia', 8),
#  ('sih', 8),
#  ('gak', 8),
#  ('lamar', 8),
#  ('dm', 8),
#  ('medan', 7),
#  ('gaji', 7),
#  ('work', 7),
#  ('anak', 7),
#  ('magang', 7),
#  ('minimal', 7),
#  ('susah', 7),
#  ('lokermedan', 6),
#  ('lupakerja', 6),
#  ('dapet', 6),
#  ('cm', 6),
#  ('temen', 6),
#  ('gimana', 6),
#  ('sales', 6),
#  ('nder', 6),
#  ('ambil', 6),
#  ('karna', 6),
#  ('nyari', 6),
#  ('guru', 6),
#  ('are', 6),
#  ('welcome', 6),
#  ('duit', 6),
#  ('bank', 6),
#  ('salah', 6),
#  ('teknisi', 6),
#  ('tips', 5),
#  ('lulus', 5),
#  ('pas', 5),
#  ('dah', 5),
#  ('hai', 5),
#  ('bgt', 5),
#  ('tp', 5),
#  ('nih', 5),
#  ('jobseeker', 5),
#  ('ortu', 5),
#  ('buka', 5),
#  ('service', 5),
#  ('administrasi', 5),
#  ('klo', 5),
#  ('pend', 5),
#  ('lowongankerja', 5),
#  ('infoloker', 5),
#  ('carikerja', 5),
#  ('udh', 5),
#  ('in', 5),
#  ('mandiri', 5),
#  ('jurusan', 5),
#  ('langsung', 5),
#  ('gini', 5),
#  ('lokasi', 5),
#  ('kegiatan', 4),
#  ('oh', 4),
#  ('liat', 4),
#  ('kak', 4),
#  ('kasih', 4),
#  ('emang', 4),
#  ('yaa', 4),
#  ('kemarin', 4),
#  ('coba', 4),
#  ('lu', 4),
#  ('a', 4),
#  ('jd', 4),
#  ('ats', 4),
#  ('belom', 4),
#  ('terbuka', 4),
#  ('sampe', 4),
#  ('pake', 4),
#  ('me', 4),
#  ('bandung', 4),
#  ('interview', 4),
#  ('mah', 4),
#  ('recruitment', 4),
#  ('bagus', 4),
#  ('berpengalaman', 4),
#  ('namanya', 4),
#  ('jg', 4),
#  ('usaha', 4),
#  ('masuk', 4),
#  ('kerjaan', 4),
#  ('dr', 4),
#  ('campus', 4),
#  ('hiring', 4),
#  ('semoga', 4),
#  ('all', 4),
#  ('perkara', 4),
#  ('maintenance', 4),
#  ('pengen', 4),
#  ('telkom', 4),
#  ('university', 4),
#  ('karyawan', 3),
#  ('universitas', 3),
#  ('ternama', 3),
#  ('yuk', 3),
#  ('mahasiswa', 3),
#  ('hr', 3),
#  ('lingkungan', 3),
#  ('mengikuti', 3),
#  ('organisasi', 3),
#  ('skill', 3),
#  ('volunteer', 3),
#  ('putra', 3),
#  ('jawa', 3),
#  ('barat', 3),
#  ('sikap', 3),
#  ('nunggu', 3),
#  ('blm', 3),
#  ('nanya', 3),
#  ('lamaran', 3),
#  ('keterima', 3),
#  ('semangat', 3),
#  ('adik', 3),
#  ('sekolah', 3),
#  ('si', 3),
#  ('ko', 3),
#  ('ni', 3),
#  ('dibuka', 3),
#  ('pendidikan', 3),
#  ('ku', 3),
#  ('jt', 3),
#  ('news', 3),
#  ('nggak', 3),
#  ('bali', 3),
#  ('kakak', 3),
#  ('tau', 3),
#  ('tertarik', 3),
#  ('link', 3),
#  ('kota', 3),
#  ('open', 3),
#  ('mu', 3),
#  ('dpt', 3),
#  ('gitu', 3),
#  ('bidang', 3),
#  ('belajar', 3),
#  ('mencari', 3),
#  ('pusat', 3),
#  ('tes', 3),
#  ('mesti', 3),
#  ('trus', 3),
#  ('ngelamar', 3),
#  ('nursery', 3),
#  ('data', 3),
#  ('bekasi', 3),
#  ('marketing', 3),
#  ('butuh', 3),
#  ('besi', 3),
#  ('teknik', 3),
#  ('x', 3),
#  ('job', 3),
#  ('company', 3),
#  ('syarikat', 3),
#  ('base', 3),
#  ('poster', 3),
#  ('alasan', 3),
#  ('beasiswa', 3),
#  ('posisi', 3),
#  ('jateng', 3),
#  ('daerah', 3),
#  ('update', 3),
#  ('baca', 3),
#  ('persyaratan', 2),
#  ('proses', 2),
#  ('tersendiri', 2),
#  ('terbaik', 2),
#  ('terkenal', 2),
#  ('ditentukan', 2),
#  ('website', 2),
#  ('informasi', 2),
#  ('kampus', 2),
#  ('berorganisasi', 2),
#  ('aktif', 2),
#  ('memiliki', 2),
#  ('dicantumkan', 2),
#  ('soft', 2),
#  ('komunitas', 2),
#  ('garudafood', 2),
#  ('jaya', 2),
#  ('timur', 2),
#  ('jam', 2),
#  ('bangka', 2),
#  ('rsu', 2),
#  ('bunda', 2),
#  ('thamrin', 2),
#  ('wkwkwkwk', 2),
#  ('kaum', 2),
#  ('auto', 2),
#  ('mandang', 2),
#  ('panca', 2),
#  ('pilar', 2),
#  ('tangguh', 2),
#  ('bumi', 2),
#  ('lestari', 2),
#  ('mengambil', 2),
#  ('takut', 2),
#  ('urusan', 2),
#  ('lg', 2),
#  ('wisuda', 2),
#  ('kirim', 2),
#  ('rejekinya', 2),
#  ('labuhanbatu', 2),
#  ('creative', 2),
#  ('gapyear', 2),
#  ('sekedar', 2),
#  ('dibayar', 2),
#  ('keje', 2),
#  ('nak', 2),
#  ('ka', 2),
#  ('team', 2),
#  ('supervisor', 2),
#  ('kualifikasi', 2),
#  ('wanita', 2),
#  ('an', 2),
#  ('km', 2),
#  ('loh', 2),
#  ('kesempatan', 2),
#  ('gausah', 2),
#  ('kayaknya', 2),
#  ('friendly', 2),
#  ('canva', 2),
#  ('word', 2),
#  ('viral', 2),
#  ('gempa', 2),
#  ('worldwar', 2),
#  ('ikatancinta', 2),
#  ('islam', 2),
#  ('muslim', 2),
#  ('haram', 2),
#  ('kpop', 2),
#  ('oppa', 2),
#  ('vaksin', 2),
#  ('peoplepower', 2),
#  ('korea', 2),
#  ('kdrama', 2),
#  ('hacker', 2),
#  ('tauhid', 2),
#  ('artis', 2),
#  ('mohon', 2),
#  ('maaf', 2),
#  ('gajinya', 2),
#  ('pariwisata', 2),
#  ('utk', 2),
#  ('tuh', 2),
#  ('gue', 2),
#  ('kayak', 2),
#  ('gas', 2),
#  ('daftar', 2),
#  ('diluar', 2),
#  ('dipersilahkan', 2),
#  ('jalan', 2),
#  ('kebeli', 2),
#  ('mobil', 2),
#  ('tua', 2),
#  ('sender', 2),
#  ('pakai', 2),
#  ('resume', 2),
#  ('i', 2),
#  ('diganti', 2),
#  ('interested', 2),
#  ('ptn', 2),
#  ('for', 2),
#  ('uda', 2),
#  ('prinsip', 2),
#  ('diterapkan', 2),
#  ('biar', 2),
#  ('hah', 2),
#  ('hoh', 2),
#  ('halo', 2),
#  ('gpp', 2),
#  ('jakpus', 2),
#  ('indra', 2),
#  ('human', 2),
#  ('dibutuhkan', 2),
#  ('klik', 2),
#  ('membuka', 2),
#  ('tu', 2),
#  ('ramah', 2),
#  ('nilai', 2),
#  ('wawancara', 2),
#  ('bikin', 2),
#  ('customer', 2),
#  ('tangkot', 2),
#  ('solusindo', 2),
#  ('bakat', 2),
#  ('tangerang', 2),
#  ('banten', 2),
#  ('kantor', 2),
#  ('luna', 2),
#  ('tama', 2),
#  ('manufakturing', 2),
#  ('gaada', 2),
#  ('gaa', 2),
#  ('deh', 2),
#  ('dom', 2),
#  ('usia', 2),
#  ('isi', 2),
#  ('ndes', 2),
#  ('dgn', 2),
#  ('min', 2),
#  ('disitu', 2),
#  ('internship', 2),
#  ('uang', 2),
#  ('paid', 2),
#  ('ig', 2),
#  ('tahap', 2),
#  ('ngerasa', 2),
#  ('y', 2),
#  ('digital', 2),
#  ('talent', 2),
#  ('goes', 2),
#  ('to', 2),
#  ('onsite', 2),
#  ('information', 2),
#  ('technology', 2),
#  ('kesempatanmu', 2),
#  ('dilaksanakan', 2),
#  ('selasa', 2),
#  ('agustus', 2),
#  ('dilatih', 2),
#  ('tagihan', 2),
#  ('serang', 2),
#  ('aceh', 2),
#  ('badan', 2),
#  ('statistik', 2),
#  ('bps', 2),
#  ('ngasih', 2),
#  ('asahan', 2),
#  ('eh', 2),
#  ('lo', 2),
#  ('kerjain', 2),
#  ('habis', 2),
#  ('terjebak', 2),
#  ('membunuh', 2),
#  ('bear', 2),
#  ('mind', 2),
#  ('saiz', 2),
#  ('standard', 2),
#  ('skop', 2),
#  ('specialization', 2),
#  ('gapapa', 2),
#  ('nd', 2),
#  ('gede', 2),
#  ('terima', 2),
#  ('apply', 2),
#  ('gua', 2),
#  ('fb', 2),
#  ('tuan', 2),
#  ('wkwk', 2),
#  ('tolong', 2),
#  ('kr', 2),
#  ('selengkapnya', 2),
#  ('electrical', 2),
#  ('gratis', 2),
#  ('telutizen', 2),
#  ('hadir', 2),
#  ('tentukan', 2),
#  ('peluang', 2),
#  ('karir', 2),
#  ('scan', 2),
#  ('barcode', 2),
#  ('akses', 2),
#  ('bertemu', 2),
#  ('impian', 2),
#  ('minimum', 2),
#  ('poin', 2),
#  ('bahasa', 2),
#  ('lelah', 2),
#  ('elektro', 2),
#  ('apaa', 2),
#  ('skrg', 2),
#  ('pegawai', 2),
#  ('penilai', 2),
#  ('th', 2),
#  ('omg', 2),
#  ('pinter', 2),
#  ('bni', 2),
#  ('tetep', 2),
#  ('wajib', 2),
#  ('headhunter', 2),
#  ('helper', 2),
#  ('receptionist', 2),
#  ('rpl', 2),
#  ('nyapu', 2),
#  ('ngepel', 2),
#  ('end', 2),
#  ('developer', 2),
#  ('laki', 2),
#  ('spesifik', 1),
#  ('rekrutmen', 1),
#  ('tantangan', 1),
#  ('tertera', 1),
#  ('kandidat', 1),
#  ('berasal', 1),
#  ('peringkat', 1),
#  ('lantas', 1),
#  ('beban', 1),
#  ('kinerja', 1),
#  ('berdasarkan', 1),
#  ('almamater', 1),
#  ('menyikapi', 1),
#  ('kondisi', 1),
#  ('melansir', 1),
#  ('laman', 1),
#  ('penyedia', 1),
#  ('jobstreet', 1),
#  ('membagikan', 1),
#  ('tipsnya', 1),
#  ('simak', 1),
#  ('kualitas', 1),
#  ('dirimu', 1),
#  ('menilai', 1),
#  ('familiar', 1),
#  ('mengandalkan', 1),
#  ('menuntut', 1),
#  ('profesionalisme', 1),
#  ('bukti', 1),
#  ('leluasa', 1),
#  ('relawan', 1),
#  ('diadakan', 1),
#  ('ngo', 1),
#  ('samosir', 1),
#  ('putri', 1),
#  ('belitung', 1),
#  ('nasibnya', 1),
#  ('pengangguran', 1),
#  ('segini', 1),
#  ('searching', 1),
#  ('jabatan', 1),
#  ('ngelunjak', 1),
#  ('ahay', 1),
#  ('apkah', 1),
#  ('tpat', 1),
#  ('wktu', 1),
#  ('xixixixi', 1),
#  ('tunduk', 1),
#  ('penjilat', 1),
#  ('malang', 1),
#  ('melintang', 1),
#  ('hadapi', 1),
#  ('lawan', 1),
#  ('senior', 1),
#  ('junior', 1),
#  ('guys', 1),
#  ('november', 1),
#  ('online', 1),
#  ('divisi', 1),
#  ('admin', 1),
#  ('sibuk', 1),
#  ('malem', 1),
#  ('gais', 1),
#  ('sabtu', 1),
#  ('tunggu', 1),
#  ('senin', 1),
#  ('makasi', 1),
#  ('titik', 1),
#  ('tercape', 1),
#  ('terjenuh', 1),
#  ('kadang', 1),
#  ('iri', 1),
#  ('dengki', 1),
#  ('seperjuangan', 1),
#  ('circle', 1),
#  ('utara', 1),
#  ('luciee', 1),
#  ('shopee', 1),
#  ('yah', 1),
#  ('good', 1),
#  ('communication', 1),
#  ('excellent', 1),
#  ('ideas', 1),
#  ('tunjukin', 1),
#  ('hoki', 1),
#  ('sch', 1),
#  ('yaaa', 1),
#  ('terjun', 1),
#  ('adaptasinya', 1),
#  ('gamudah', 1),
#  ('nikmatin', 1),
#  ('kangen', 1),
#  ('bojonegoro', 1),
#  ('semudah', 1),
#  ('kawan', 1),
#  ('drama', 1),
#  ('series', 1),
#  ('dalamnya', 1),
#  ('new', 1),
#  ('genio', 1),
#  ('cakep', 1),
#  ('jah', 1),
#  ('tar', 1),
#  ('dlu', 1),
#  ('tabungan', 1),
#  ('kekumpul', 1),
#  ('wakakakaka', 1),
#  ('madiun', 1),
#  ('oengalaman', 1),
#  ('bape', 1),
#  ('yelah', 1),
#  ('kite', 1),
#  ('bontang', 1),
#  ('tabe', 1),
#  ('lokerta', 1),
#  ('guyss', 1),
#  ('hehe', 1),
#  ('join', 1),
#  ('our', 1),
#  ('mitra', 1),
#  ('pratama', 1),
#  ('mobilindo', 1),
#  ('jogja', 1),
#  ('executive', 1),
#  ('executve', 1),
#  ('pria', 1),
#  ('smu', 1),
#  ('teluk', 1),
#  ('bintuni', 1),
#  ('mutualan', 1),
#  ('twitter', 1),
#  ('ditempat', 1),
#  ('diriku', 1),
#  ('karawang', 1),
#  ('sis', 1),
#  ('enaknya', 1),
#  ('ngapain', 1),
#  ('bengkulu', 1),
#  ('cmu', 1),
#  ('stanford', 1),
#  ('bachelor', 1),
#  ('of', 1),
#  ('nama', 1),
#  ('jurusanmu', 1),
#  ('future', 1),
#  ('scientist', 1),
#  ('kl', 1),
#  ('depannya', 1),
#  ('ambis', 1),
#  ('penemu', 1),
#  ('obat', 1),
#  ('gt', 1),
#  ('didepan', 1),
#  ('mata', 1),
#  ('milih', 1),
#  ('sikat', 1),
#  ('langkat', 1),
#  ('code', 1),
#  ('programmer', 1),
#  ('laravel', 1),
#  ('harapan', 1),
#  ('koo', 1),
#  ('rezeki', 1),
#  ('ju', 1),
#  ('penawaran', 1),
#  ('umr', 1),
#  ('gk', 1),
#  ('smpe', 1),
#  ('objeknya', 1),
#  ('positif', 1),
#  ('thinking', 1),
#  ('ez', 1),
#  ('ngerasain', 1),
#  ('nganggur', 1),
#  ('yakan', 1),
#  ('inpo', 1),
#  ('lgsg', 1),
#  ('posternya', 1),
#  ('jends', 1),
#  ('padangsidempuan', 1),
#  ('seukuran', 1),
#  ('dibolehin', 1),
#  ('posisinya', 1),
#  ('app', 1),
#  ('sinarmas', 1),
#  ('penempatan', 1),
#  ('batam', 1),
#  ('satunya', 1),
#  ('mengubah', 1),
#  ('nasib', 1),
#  ('kepingin', 1),
#  ('spy', 1),
#  ('realita', 1),
#  ('murah', 1),
#  ('pokoknya', 1),
#  ('kalah', 1),
#  ('mental', 1),
#  ('kalp', 1),
#  ('ngehadepin', 1),
#  ('umur', 1),
#  ('nanyaa', 1),
#  ('jajan', 1),
#  ('gmn', 1),
#  ('sungkan', 1),
#  ('ayots', 1),
#  ('buset', 1),
#  ('yatim', 1),
#  ('gw', 1),
#  ('malinau', 1),
#  ('lhokseumawe', 1),
#  ('architecture', 1),
#  ('planning', 1),
#  ('tergolong', 1),
#  ('ngumpulin', 1),
#  ('resumenya', 1),
#  ('bagusnya', 1),
#  ('ngga', 1),
#  ('br', 1),
#  ('about', 1),
#  ('am', 1),
#  ('asset', 1),
#  ('management', 1),
#  ('from', 1),
#  ('politeknik', 1),
#  ('negeri', 1),
#  ('nyebut', 1),
#  ('siklus', 1),
#  ('aset', 1),
#  ('sebutin', 1),
#  ('expertise', 1),
#  ('kmu', 1),
#  ('bground', 1),
#  ('kejuruan', 1),
#  ('hukum', 1),
#  ('ragu', 1),
#  ('joki', 1),
#  ('fh', 1),
#  ('ngerjainnya', 1),
#  ('ngasal', 1),
#  ('more', 1),
#  ('yaaah', 1),
#  ('matkul', 1),
#  ('bisaaa', 1),
#  ('dipanggil', 1),
#  ('seneng', 1),
#  ('diperhatiin', 1),
#  ('nggaknya', 1),
#  ('gamau', 1),
#  ('sharing', 1),
#  ('jargon', 1),
#  ('terms', 1),
#  ('dipake', 1),
#  ('sehari', 1),
#  ('first', 1),
#  ('day', 1),
#  ('thread', 1),
#  ('freelancer', 1),
#  ('lt', 1),
#  ('trims', 1),
#  ('here', 1),
#  ('provide', 1),
#  ('my', 1),
#  ('bantu', 1),
#  ('memulakan', 1),
#  ('langkah', 1),
#  ('iaitu', 1),
#  ('harga', 1),
#  ('serendah', 1),
#  ('rm', 1),
#  ('sahaja', 1),
#  ('sepenuhnya', 1),
#  ('djarum', 1),
#  ('permanen', 1),
#  ('sarjana', 1),
#  ('janis', 1),
#  ('astraworld', 1),
#  ('astra', 1),
#  ('international', 1),
#  ('tbk', 1),
#  ('tgk', 1),
#  ('bru', 1),
#  ('start', 1),
#  ('pkai', 1),
#  ('myvi', 1),
#  ('facelit', 1),
#  ('pehhh', 1),
#  ('dik', 1),
#  ('sayang', 1),
#  ('tydak', 1),
#  ('it', 1),
#  ('selebihnya', 1),
#  ('berdoa', 1),
#  ('usahakan', 1),
#  ('org', 1),
#  ('jahat', 1),
#  ('sumpah', 1),
#  ('goblok', 1),
#  ('tbtb', 1),
#  ('dateng', 1),
#  ('jimmagro', 1),
#  ('inter', 1),
#  ('mulya', 1),
#  ('menjaga', 1),
#  ('menata', 1),
#  ('kerapian', 1),
#  ('kebersihan', 1),
#  ('lokerpalembang', 1),
#  ('breaking', 1),
#  ('istri', 1),
#  ('bos', 1),
#  ('ngaku', 1),
#  ('diancam', 1),
#  ('dilecehkan', 1),
#  ('suaminya', 1),
#  ('ingpo', 1),
#  ('ndoro', 1),
#  ('restu', 1),
#  ('lancar', 1),
#  ('sentosa', 1),
#  ('kemampuan', 1),
#  ('komunikasi', 1),
#  ('lokerjawatimur', 1),
#  ('kyknya', 1),
#  ('aturan', 1),
#  ('penjas', 1),
#  ('proporsional', 1),
#  ('badannya', 1),
#  ('olahraga', 1),
#  ('rada', 1),
#  ('pincang', 1),
#  ('sm', 1),
#  ('muda', 1),
#  ('kab', 1),
#  ('cewek', 1),
#  ('bergerak', 1),
#  ('dibidang', 1),
#  ('provider', 1),
#  ('internet', 1),
#  ('manage', 1),
#  ('oalah', 1),
#  ('bh', 1),
#  ('setau', 1),
#  ('bebas', 1),
#  ('pembatasan', 1),
#  ('batasan', 1),
#  ('kelulusan', 1),
#  ('ut', 1),
#  ('rumah', 1),
#  ('tangga', 1),
#  ('pekerja', 1),
#  ('dsni', 1),
#  ('eits', 1),
#  ('diem', 1),
#  ('ygy', 1),
#  ('mendingan', 1),
#  ('mempercantik', 1),
#  ('cewe', 1),
#  ('semarang', 1),
#  ('gass', 1),
#  ('pribadi', 1),
#  ('ttp', 1),
#  ('jalanin', 1),
#  ('orientasinya', 1),
#  ('dibanding', 1),
#  ('berati', 1),
#  ('mengabaikan', 1),
#  ('belibet', 1),
#  ('gaksi', 1),
#  ('bahasanya', 1),
#  ('ok', 1),
#  ('mencapai', 1),
#  ('pandai', 1),
#  ('pedang', 1),
#  ('keris', 1),
#  ('senjata', 1),
#  ('menguasai', 1),
#  ('menempa', 1),
#  ('walk', 1),
#  ('bawa', 1),
#  ('portofolio', 1),
#  ('candi', 1),
#  ('bajang', 1),
#  ('ratu', 1),
#  ('desa', 1),
#  ('temon', 1),
#  ('kecamatan', 1),
#  ('trowulan', 1),
#  ('kebumen', 1),
#  ('iya', 1),
#  ('bang', 1),
#  ('fokusnya', 1),
#  ('salary', 1),
#  ('ny', 1),
#  ('digit', 1),
#  ('wkwkw', 1),
#  ('suaranya', 1),
#  ('nambah', 1),
#  ('pertamina', 1),
#  ('durasi', 1),
#  ('saku', 1),
#  ('source', 1),
#  ('pertaminacareer', 1),
#  ('bener', 1),
#  ('bodoh', 1),
#  ('kelas', 1),
#  ('mostly', 1),
#  ('beliau', 1),
#  ('kerasa', 1),
#  ('tertinggal', 1),
#  ('keras', 1),
#  ('dimana', 1),
#  ('engga', 1),
#  ('anakku', 1),
#  ('duwa', 1),
#  ('bengong', 1),
#  ('wqwqwq', 1),
#  ('jgn', 1),
#  ('mencoba', 1),
#  ('pede', 1),
#  ('lumajang', 1),
#  ('tweet', 1),
#  ('jurug', 1),
#  ('mas', 1),
#  ('gibran', 1),
#  ('desk', 1),
#  ('menghitung', 1),
#  ('jasa', 1),
#  ('medis', 1),
#  ('dokter', 1),
#  ('memproses', 1),
#  ('klaim', 1),
#  ('asuransi', 1),
#  ('pembayaran', 1),
#  ('suplier', 1),
#  ('rekonsiliasi', 1),
#  ('rekening', 1),
#  ('intanaka', 1),
#  ('produksi', 1),
#  ('banda', 1),
#  ('denpasar', 1),
#  ('pontianak', 1),
#  ('cerita', 1),
#  ('calon', 1),
#  ('kesana', 1),
#  ('kesini', 1),
#  ('camer', 1),
#  ('modal', 1),
#  ('berat', 1),
#  ('keluarga', 1),
#  ('membandingkan', 1),
#  ('sepupu', 1),
#  ('teh', 1),
#  ('dewasaaaa', 1),
#  ('aaaaaaaaaaaaaa', 1),
#  ('kuat', 1),
#  ('tidore', 1),
#  ('kepulauan', 1),
#  ('pelatihan', 1),
#  ('astaga', 1),
#  ('nyusun', 1),
#  ('blom', 1),
#  ('kategori', 1),
#  ('sirik', 1),
#  ('nderrr', 1),
#  ('jual', 1),
#  ('mahal', 1),
#  ('selagi', 1),
#  ('ajaa', 1),
#  ('nnti', 1),
#  ('ngikutt', 1),
#  ('minat', 1),
#  ('multitask', 1),
#  ('and', 1),
#  ('servicing', 1),
#  ('please', 1),
#  ('details', 1),
#  ('allowance', 1),
#  ('provided', 1),
#  ('okay', 1),
#  ('freshgraduate', 1),
#  ('kerjakosong', 1),
#  ('kemaman', 1),
#  ('kuantan', 1),
#  ('kulon', 1),
#  ('progo', 1),
#  ('palu', 1),
#  ('berguna', 1),
#  ('sesuai', 1),
#  ('keinginanmu', 1),
#  ('malu', 1),
#  ('kebiasaan', 1),
#  ('hiraukan', 1),
#  ('bantuannya', 1),
#  ('headline', 1),
#  ('terhitung', 1),
#  ('diterima', 1),
#  ('merenung', 1),
#  ('pastikan', 1),
#  ('disana', 1),
#  ('plis', 1),
#  ('awam', 1),
#  ('bnyak', 1),
#  ('pertanya', 1),
#  ('kepala', 1),
#  ('done', 1),
#  ('rt', 1),
#  ('n', 1),
#  ('trick', 1),
#  ('pendapat', 1),
#  ('dikerah', 1),
#  ('like', 1),
#  ('video', 1),
#  ('editing', 1),
#  ('scope', 1),
#  ('selepas', 1),
#  ('extra', 1),
#  ('dijanjikan', 1),
#  ('sumbang', 1),
#  ('kasi', 1),
#  ('diskon', 1),
#  ('cafe', 1),
#  ('doalnya', 1),
#  ('duitnya', 1),
#  ('sberapa', 1),
#  ('hey', 1),
#  ('berjuang', 1),
#  ('phoebe', 1),
#  ('sulit', 1),
#  ('nagekeo', 1),
#  ('wasit', 1),
#  ('kali', 1),
#  ('iuaga', 1),
#  ('euy', 1),
#  ('serius', 1),
#  ('bingung', 1),
#  ('dokumen', 1),
#  ('siapkan', 1),
#  ('pencerahan', 1),
#  ('berusaha', 1),
#  ('improve', 1),
#  ('bentar', 1),
#  ('ttd', 1),
#  ('kontrak', 1),
#  ('penilaianlah', 1),
#  ('dikasih', 1),
#  ('user', 1),
#  ('cuman', 1),
#  ('cont', 1),
#  ('weiiiii', 1),
#  ('sii', 1),
#  ('bgstt', 1),
#  ('bisaa', 1),
#  ('gilaa', 1),
#  ('dirumah', 1),
#  ('trusss', 1),
#  ('suuuu', 1),
#  ('batas', 1),
#  ('rs', 1),
#  ('medical', 1),
#  ('center', 1),
#  ('jmc', 1),
#  ('apoteker', 1),
#  ('cek', 1),
#  ('pastry', 1),
#  ('baker', 1),
#  ('rumahan', 1),
#  ('but', 1),
#  ('percaya', 1),
#  ('kerjaa', 1)]

# %%
#  Distribusi bi-gram
result = pd.Series(nltk.ngrams(cleans, 2)).value_counts()[:25]
print (result)
# Out:
# (lowongan, kerja)          66
# (sma, smk)                 27
# (kerja, program)           25
# (pt, indah)                25
# (indah, reksa)             25
# (reksa, equality)          25
# (lulusan, sma)             21
# (kerja, jakarta)           19
# (hubungi, wa)              18
# (smk, jujur)               18
# (disiplin, hubungi)        18
# (jujur, disiplin)          18
# (selatan, cabang)          18
# (orang, lulusan)           18
# (cabang, orang)            18
# (jakarta, selatan)         18
# (wa, lowongan)             14
# (dunia, kerja)              9
# (info, loker)               8
# (are, welcome)              6
# (lokermedan, lupakerja)     6
# (minimal, sma)              5
# (lamar, loker)              5
# (kerja, administrasi)       5
# (equality, lowongan)        5
# dtype: int64

# %%
#  slang word pembersihan + kata kunci pencarian
slangWords = ['sabi','sabun','sabeb','kilab','cabs','sutup','selow',' woles','baper','php','rokum','sotoy','btw','krn','rl','bgt','w','fak','lbh','tp','bgt','sm','wkwk','trs','emg','dh','gt','jln','eh','dr','blm','se','ma','tmn','k','putus','amp','twb','nd','buset']
def slang_words(text):
    texts = text.split()
    
    resultword = [word for word in texts if word not in slangWords]
    hasil = ' '.join(resultword)
    return hasil

# %%
df['clean_artikel'] = df['clean_artikel'].apply(slang_words)
df.drop('clean_artikel_frequency', inplace=True, axis=1)
df
# Out:
#                                                artikel  \
# 0
# 1     - Saat ini perusahaan sangat spesifik dalam m...
# 2    Bahkan di beberapa persyaratan lowongan kerja,...
# 3    Lantas bagaimana fresh graduate dari universit...
# 4    Menyikapi kondisi ini, ada beberapa tips yang ...
# ..                                                 ...
# 215  Info loker dom bogor dong buat SMK fresh gradu...
# 216  @collegemenfess sama aja nder, tapi kalo kerja...
# 217  Fresh Graduate Wajib Tahu, Ini Hal yang Mesti ...
# 218  [cm] di LinkedIn ada ga yang buka lowongan bua...
# 219   @hrdbacot fresh graduate boleh lamar ga kak? 🙏🙏🙏
#
#                                          clean_artikel
# 0
# 1    perusahaan spesifik persyaratan proses rekrutm...
# 2    persyaratan lowongan kerja tertera syarat kand...
# 3    lantas universitas terkenal syarat beban terse...
# 4    menyikapi kondisi tips melansir laman website ...
# ..                                                 ...
# 215  info loker dom bogor smk butuh kerjaan banget ...
# 216  aja nder kalo kerja praktek kayaknya undergrad...
# 217              wajib mesti diperhatikan bikin cv ats
# 218  cm linkedin ga buka lowongan magang statusnya ...
# 219                                       lamar ga kak
#
# [220 rows x 2 columns]

# %% [markdown]
# Data Processing

# %%
# Mengubah data teks menjadi numerik
features = df['clean_artikel']

#create tokenizer for our data
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=5000, oov_token='<UNK>')
tokenizer.fit_on_texts(features)


#convert text data to numerical indexes
data_num = tokenizer.texts_to_sequences(features)

#pad data up to SEQ_LEN (note that we truncate if there are more than SEQ_LEN tokens)
data_num = tf.keras.preprocessing.sequence.pad_sequences(data_num, padding="post", maxlen=20)

# %%
data_num
# Out:
# array([[   0,    0,    0, ...,    0,    0,    0],
#        [  28,  425,  202, ...,    0,    0,    0],
#        [ 202,    3,    2, ...,    0,    0,    0],
#        ...,
#        [ 415,  179, 1184, ...,    0,    0,    0],
#        [  57, 1185,    7, ..., 1190,  381,   99],
#        [  45,    7,   98, ...,    0,    0,    0]])

# %%
#menentukan banyak kelas yang optimal

print('Elbow Method to determine the number of clusters to be formed:')
Elbow_M = KElbowVisualizer(KMeans(), k=10)
Elbow_M.fit(data_num)
Elbow_M.show()
# Out:
# Elbow Method to determine the number of clusters to be formed:
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# Modeling

# %%
AC = AgglomerativeClustering(n_clusters=4)
# fit model and predict clusters
yhat_AC = AC.fit_predict(data_num)
df["Clusters"] = yhat_AC

# %%
# visualisasi hasil cluster
sns.barplot(df['Clusters'].value_counts().index,df['Clusters'].value_counts())
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='Clusters'>

# %%
# data frame setelalah di cluster
df
# Out:
#                                                artikel  \
# 0
# 1     - Saat ini perusahaan sangat spesifik dalam m...
# 2    Bahkan di beberapa persyaratan lowongan kerja,...
# 3    Lantas bagaimana fresh graduate dari universit...
# 4    Menyikapi kondisi ini, ada beberapa tips yang ...
# ..                                                 ...
# 215  Info loker dom bogor dong buat SMK fresh gradu...
# 216  @collegemenfess sama aja nder, tapi kalo kerja...
# 217  Fresh Graduate Wajib Tahu, Ini Hal yang Mesti ...
# 218  [cm] di LinkedIn ada ga yang buka lowongan bua...
# 219   @hrdbacot fresh graduate boleh lamar ga kak? 🙏🙏🙏
#
#                                          clean_artikel  Clusters
# 0                                                              1
# 1    perusahaan spesifik persyaratan proses rekrutm...         1
# 2    persyaratan lowongan kerja tertera syarat kand...         1
# 3    lantas universitas terkenal syarat beban terse...         1
# 4    menyikapi kondisi tips melansir laman website ...         3
# ..                                                 ...       ...
# 215  info loker dom bogor smk butuh kerjaan banget ...         2
# 216  aja nder kalo kerja praktek kayaknya undergrad...         2
# 217              wajib mesti diperhatikan bikin cv ats         1
# 218  cm linkedin ga buka lowongan magang statusnya ...         0
# 219                                       lamar ga kak         1
#
# [220 rows x 3 columns]

# %%
df1 = pd.DataFrame(df[(df["Clusters"]== 0)]["clean_artikel"])
df2 = pd.DataFrame(df[(df["Clusters"]== 1)]["clean_artikel"])
df3 = pd.DataFrame(df[(df["Clusters"]== 2)]["clean_artikel"])
df4 = pd.DataFrame(df[(df["Clusters"]== 3)]["clean_artikel"])

df1.columns = ['class_1']
df2.columns = ['class_2']
df3.columns = ['class_3']
df4.columns = ['class_4']

# %%
df1['1_artikel_frequency']  = df1["class_1"].apply(lambda x: word_tokenize(x))
cleans_1 = [word for clean in df1['1_artikel_frequency'] for word in clean]
result = pd.Series(nltk.ngrams(cleans_1, 2)).value_counts()[:25]
print (result)
# Out:
# (info, loker)            4
# (lowongan, kerja)        4
# (pengalaman, kerja)      3
# (ga, sih)                3
# (lulusan, smk)           3
# (dapet, kerja)           2
# (lokasi, melamar)        2
# (melamar, baca)          2
# (end, developer)         2
# (kerja, gaji)            2
# (syarat, lokasi)         2
# (update, september)      2
# (dunia, kerja)           2
# (hah, hoh)               2
# (cari, pengalaman)       2
# (pengen, ngelanjutin)    1
# (ngelanjutin, basic)     1
# (basic, kelistrikan)     1
# (banget, pengen)         1
# (susah, banget)          1
# (smk, susah)             1
# (kelistrikan, smk)       1
# (smk, cari)              1
# (dll, lulusan)           1
# (pengalaman, pengen)     1
# dtype: int64

# %%
df2['2_artikel_frequency']  = df2["class_2"].apply(lambda x: word_tokenize(x))
cleans_2 = [word for clean in df2['2_artikel_frequency'] for word in clean]
result = pd.Series(nltk.ngrams(cleans_2, 2)).value_counts()[:25]
print (result)
# Out:
# (lowongan, kerja)         51
# (kerja, program)          25
# (indah, reksa)            25
# (reksa, equality)         25
# (pt, indah)               25
# (sma, smk)                19
# (selatan, cabang)         18
# (cabang, orang)           18
# (orang, lulusan)          18
# (smk, jujur)              18
# (jakarta, selatan)        18
# (jujur, disiplin)         18
# (disiplin, hubungi)       18
# (hubungi, wa)             18
# (kerja, jakarta)          18
# (lulusan, sma)            18
# (wa, lowongan)            16
# (equality, lowongan)       9
# (kerja, administrasi)      5
# (ga, ya)                   3
# (info, loker)              3
# (pengalaman, kerja)        2
# (banten, lowongan)         2
# (human, recruitment)       2
# (program, labuhanbatu)     2
# dtype: int64

# %%
df3['3_artikel_frequency']  = df3["class_3"].apply(lambda x: word_tokenize(x))
cleans_3 = [word for clean in df3['3_artikel_frequency'] for word in clean]
result = pd.Series(nltk.ngrams(cleans_3, 2)).value_counts()[:25]
print (result)
# Out:
# (are, welcome)                3
# (loker, lowongankerja)        2
# (masuk, kuliah)               2
# (syarat, pend)                2
# (pend, minimal)               2
# (minimal, sma)                2
# (sma, smk)                    2
# (smk, are)                    2
# (lamar, loker)                2
# (lowongankerja, infoloker)    2
# (infoloker, carikerja)        2
# (lowongan, magang)            2
# (nyapu, ngepel)               2
# (loker, teknisi)              2
# (magang, statusnya)           1
# (lolos, tahap)                1
# (lulus, udah)                 1
# (sblm, lulus)                 1
# (apply, sblm)                 1
# (interested, apply)           1
# (recruiter, interested)       1
# (tag, recruiter)              1
# (headhunter, tag)             1
# (dilatih, headhunter)         1
# (mentor, dilatih)             1
# dtype: int64

# %%
df4['4_artikel_frequency']  = df4["class_4"].apply(lambda x: word_tokenize(x))
cleans_4 = [word for clean in df4['4_artikel_frequency'] for word in clean]
result = pd.Series(nltk.ngrams(cleans_4, 2)).value_counts()[:25]
print (result)
# Out:
# (lowongan, kerja)             11
# (lokermedan, lupakerja)        6
# (sma, smk)                     6
# (telkom, university)           4
# (medan, s)                     4
# (dunia, kerja)                 4
# (campus, hiring)               4
# (perusahaan, yg)               3
# (oh, gini)                     3
# (september, pt)                3
# (s, s)                         3
# (kerja, medan)                 3
# (medan, lulusan)               3
# (d, medan)                     3
# (syarat, pend)                 3
# (lulusan, d)                   3
# (pend, minimal)                3
# (minimal, sma)                 3
# (smk, are)                     3
# (are, welcome)                 3
# (infoloker, carikerja)         3
# (lowongankerja, infoloker)     3
# (loker, lowongankerja)         3
# (lamar, loker)                 3
# (d, september)                 3
# dtype: int64

# %% [markdown]
# Worcloud

# %%
# dataframe to teks
df1.to_csv(r'class_1.txt', header=None, index=None, sep=' ', mode='a')
df2.to_csv(r'class_2.txt', header=None, index=None, sep=' ', mode='a')
df3.to_csv(r'class_3.txt', header=None, index=None, sep=' ', mode='a')
df4.to_csv(r'class_4.txt', header=None, index=None, sep=' ', mode='a')

# %%
f1 = open("class_1.txt", "r")
f2 = open("class_2.txt", "r")
f3 = open("class_3.txt", "r")
f4 = open("class_4.txt", "r")


isi_text1 = f1.read()
isi_text2 = f2.read()
isi_text3 = f3.read()
isi_text4 = f4.read()


wordcloud = WordCloud(width=1600, height=800, max_font_size=200, background_color='white')

# %%
#wordclud class 1
wordcloud.generate(isi_text1)
plt.figure(figsize=(12,10))

plt.imshow(wordcloud, interpolation='bilinear')

plt.axis("off")

plt.show()

# %%
#wordclud class 2
wordcloud.generate(isi_text2)
plt.figure(figsize=(12,10))

plt.imshow(wordcloud, interpolation='bilinear')

plt.axis("off")

plt.show()

# %%
#wordclud class 3
wordcloud.generate(isi_text3)
plt.figure(figsize=(12,10))

plt.imshow(wordcloud, interpolation='bilinear')

plt.axis("off")

plt.show()

# %%
#wordclud class 4
wordcloud.generate(isi_text4)
plt.figure(figsize=(12,10))

plt.imshow(wordcloud, interpolation='bilinear')

plt.axis("off")

plt.show()
